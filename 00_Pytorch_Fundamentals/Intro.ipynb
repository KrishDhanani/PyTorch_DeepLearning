# %% [markdown]
# <img src="img1.png">

# %% [markdown]
# <img src="img2.png">

# %% [markdown]
# <img src="img3.png">

# %% [markdown]
# <img src="img4.png">

# %% [markdown]
# ## What is Pytorch?

# %% [markdown]
# <img src="img5.png">

# %% [markdown]
# ## What are tensors?

# %% [markdown]
# <img src="img6.png">

# %% [markdown]
# <img src="img7.png">

# %% [markdown]
# <img src="img8.png">
